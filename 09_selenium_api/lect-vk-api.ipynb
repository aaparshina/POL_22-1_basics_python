# %% [markdown]
# # Основы программирования в Python
#
# *Алла Тамбовцева, НИУ ВШЭ*

# %% [markdown]
# ### Работа с API: пример с API ВКонтакте

# %% [markdown]
# Сегодня мы немного поработаем с API. API – программный интерфейс приложения, сокращение от *Application Programming Interface*. Этот интерфейс позволяет выполнять различные операции автоматически, через приложение. Если API нам нужен исключительно как источник данных, можно писать запросы, позволяющие обратиться к хранилищу информации внутри API. Если мы хотим управлять приложением, которое будет выполнять какие-то действия, удаленно, можно написать код, который будет, например, автоматически отвечать на сообщения, когда мы не онлайн, лайкать новый пост друга через 30 секунд после его появления, пересылать на почту фотографии, которые выложили участники диалога и прочее.
#
# Мы будем работать с API социальной сети ВКонтакте. Использовать API для написания и приема сообщений средствами Python мы не будем, а рассмотрим API как источник данных, позволяющий выгрузить все посты со стены пользователя или сообщества. Для работы нам понадобится библиотека `vk`, ее нужно установить через `pip install vk` в *Anaconda Command Prompt* (см. пример с `selenium` [здесь](https://nbviewer.jupyter.org/github/allatambov/Py-programming-3/blob/master/11-06/lect-selenium1.ipynb)).
#
# Импортируем библиотеку:

# %%
# !pip install vk
# Out:
# Collecting vk
#   Downloading vk-2.0.2.tar.gz (7.0 kB)
# Requirement already satisfied: requests<3.0,>=2.8 in ./opt/anaconda3/lib/python3.9/site-packages (from vk) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8->vk) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8->vk) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8->vk) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8->vk) (3.2)
# Building wheels for collected packages: vk
#   Building wheel for vk (setup.py) ... done
#   Created wheel for vk: filename=vk-2.0.2-py3-none-any.whl size=8275 sha256=dce0e0ae119984640e9a4aabea3efdbcadbf9c9ccbe5291f2b7178cd5d3598b7
#   Stored in directory: /Users/anastasiaparsina/Library/Caches/pip/wheels/18/12/65/557eef2d4aaeab693bd15ed182ad993bd0a1b3fbe774b474a0
# Successfully built vk
# Installing collected packages: vk
# Successfully installed vk-2.0.2

# %%
import vk

# %% [markdown]
# Теперь нужно авторизоваться: создать приложение и получить токен доступа к нему.

# %% [markdown]
# #### Для авторизации:
#
# 1. [Создать](https://vk.com/apps?act=manage) приложение ВКонтакте (пройти по ссылке). Дать название, выбрать *Standalone-приложение*.
# 2. Включить приложение, сделать публичным (*Настройки - Состояние* и выбрать в выпадающем меню *Приложение включено и видно всем*).
# 3. Авторизоваться: скопировать строку ниже в браузер, в `client id` вместо 1 выставить `id` своего приложения (первая строка в настроках ‒ *ID приложения*). Если не хочется ни в чем ограничивать свое приложение, можно оставить `scope=all` (у приложения будет доступ ко всему, к чему есть доступ у пользователя).
#
#     > ```https://oauth.vk.com/authorize?client_id=1&display=page&redirect_uri=http://oauth.vk.com/blank.html&scope=all&response_type=token```
#
# 4. Скопировать `access token` из обновленной адресной строки (все после `access_token=` и до `&expires_in`, без `&`). Никому не показывать! По этому токену можно получить доступ ко всему аккаунту.

# %%
# скопировать свой access token без пробелов вместо 1234 
token = '1234'

# %%
session = vk.Session(access_token = token) # открыть сессию для работы
api = vk.API(session) # подключиться к API

# %% [markdown]
# Попробуем сгрузить первые 100 постов со [стены](https://vk.com/hseofficial) неофициального сообщества ВШЭ. Сохраним ссылку на сообщество в переменную `group`:

# %%
group = 'hseofficial'

# %% [markdown]
# Обратите внимание: ссылка должна быть относительной, то есть без части с `https:/vk.com/`. Python и так будет знать, что мы работаем с сетью ВКонтакте.

# %% [markdown]
# Теперь получим доступ к стене этого сообщества:

# %%
# wall.get - "подключаемся" к стене
# count - сколько постов выгрузить (максимум)
# v - версия API, можно обойтись без нее, но Python может выдать warning

res = api.wall.get(domain = group, count = 100, v = 5.131)

# %%
api.wall.getComments(owner_id = -42744677, post_id = 316221, count = 100, v = 5.131)
# Out:
# {'count': 10,
#  'items': [{'id': 316222,
#    'from_id': 235120667,
#    'date': 1649688506,
#    'text': 'почему можно покупать кошек и собак, а людей нет?',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 1,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316223,
#    'from_id': 684996161,
#    'date': 1649688740,
#    'text': '',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -8,
#       'date': 1649688740,
#       'id': 457270331,
#       'owner_id': -42744677,
#       'access_key': 'e62677806032d82563',
#       'sizes': [{'height': 49,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/Xvc27r2DMtyk2KSEfWOX0_DsfK5oy74o4MhaxnzK1y66pUFx80C0_1owzBccMXoQ4l6UIT3mReuvoGfk4boyVDij.jpg?size=75x49&quality=95&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 85,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/Y2ZZdYnAA6vRTqag5aNWNJiCOUHB6M3yYPXb5j3ieXGwoNs-3v3rqqO846f913bapNujPDeesIbxqTlatofH-fcS.jpg?size=130x85&quality=95&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 393,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/UiHFOkKuy2ZfONGqOELThBsD_hkeZpjSzrRNMDVv9229jUfR6HhL7rf6oL3-1WBQnuyr2mDhOvdKmfeaZerNIZXh.jpg?size=604x393&quality=95&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 469,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/rJ4PZizAar0JG4wk2x6ncBzUtucY-SgRWN51XKIi0ovd-7q23P3d6CaxRzLifzGuPbeo8H0sO0CJIZlB-cg3VktY.jpg?size=720x469&quality=95&type=album',
#         'type': 'y',
#         'width': 720},
#        {'height': 87,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/SEfBljmbgxHxLoygiwF0Dg_QOUZ0cu6JW-bCL6DzmfWXO0lOvQhFG9A-Uvl4BI_7clK-I8qAYvMenpHvWDAijDr5.jpg?size=130x87&quality=95&crop=9,0,701,469&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/f_fB7HuXYIg9oz4Ey1YlH8jL5Cz-Av1hpgl24Vno5HO_70LSexR9Zuz35bhQ-3uJs1uUDyfim7Og-9TqQtSHEdz1.jpg?size=200x133&quality=95&crop=7,0,705,469&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/DvbRTmYuVlNyfEgsTWcb662Gb_N_HmCkIbJtDBi_kCOJ2bBCRbxV1mq1ZsSjN8JUlnyGZldYtModBb1LKk_fwaY2.jpg?size=320x213&quality=95&crop=7,0,705,469&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun9-33.userapi.com/s/v1/if2/6smhPry6Q8aulHSWKvW1V-ttGve2deC5PQ1OwC64WCiqXatUjAKJQfpKeW6ah8LkPyeO_ybPBTsZ9sYoC-Psc4U2.jpg?size=510x340&quality=95&crop=8,0,703,469&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 684996161,
#       'has_tags': False}}],
#    'thread': {'count': 1,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316224,
#    'from_id': 616661068,
#    'date': 1649690059,
#    'text': 'Stay with cats. Twice the fun!',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316225,
#    'from_id': 214849518,
#    'date': 1649690171,
#    'text': 'Админ на капитализме совсем кукухой поехал и забыл, что собак заводят',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 1,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316231,
#    'from_id': 27199917,
#    'date': 1649698190,
#    'text': 'Какие хорошие флаги!',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316419,
#    'from_id': 264505659,
#    'date': 1649820623,
#    'text': 'Захожу в этот телеграм-канал исключительно из-за одной лишь только кошки. Однако, к сожалению, в эфир её практически не выпускают.',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}},
#   {'id': 316798,
#    'from_id': 214276671,
#    'date': 1650170384,
#    'text': 'Ох, и весело тебе жить будет!',
#    'post_id': 316221,
#    'owner_id': -42744677,
#    'parents_stack': [],
#    'thread': {'count': 0,
#     'items': [],
#     'can_post': True,
#     'show_reply_button': True,
#     'groups_can_post': True}}],
#  'current_level_count': 7,
#  'can_post': True,
#  'show_reply_button': True,
#  'groups_can_post': True}

# %%
res
# Out:
# {'count': 19276,
#  'items': [{'id': 316221,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1649688300,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '🇺🇦🇵🇱 Подписывайся на tg канал Westerly! \n\nЭто не тупое копирование постов из группы. Это на 90% уникальный контент, которого там больше, чем в VK. Так что не выключай уведомления и следи за новостями. Ссылка в источнике👇🏻\n\nА еще я по вечерам публикую там фото своей кошки, она очень милая. А на неделе я куплю еще и собаку🥰',
#    'is_pinned': 1,
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': 193711964,
#       'date': 1547569728,
#       'id': 456269537,
#       'owner_id': 109145547,
#       'access_key': '197569647a9a6d2da3',
#       'sizes': [{'height': 130,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/YGBGKkb61-QF3nXum9n-CIGWSSdL4_N1EH_kNlAOOVG4DaYlU3mD2jTEwIjI35P4VOTN5KuG.jpg?size=130x130&quality=96&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 130,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/YGBGKkb61-QF3nXum9n-CIGWSSdL4_N1EH_kNlAOOVG4DaYlU3mD2jTEwIjI35P4VOTN5KuG.jpg?size=130x130&quality=96&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 200,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/KXhBDyDZ3fpiyrIPZ0NJKVM5uYX0BLmqh4TOucGy3BWsoPJ4uQ6A07ycpE720vS3DTf6n_ID.jpg?size=200x200&quality=96&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 320,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/n3b1yY6WYnBGahCwZa5PYRJBnqSA8duN57sfelSt_NqZmy1ru2Whw4K4Yx6JHZiExqf4TCfw.jpg?size=320x320&quality=96&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 510,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/YYce4CE4jRIBEfJ7Wlw2V-giAmEtPq19cODj0dN89yti_KWcD1PLSNBAC0umRZ8BcrqDCj7a.jpg?size=510x510&quality=96&type=album',
#         'type': 'r',
#         'width': 510},
#        {'height': 75,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/F0S4iW3nZAw9z93vR0ZYAy5GfocarVwbbXX5BLD-PUejZGOL67I2vWKvaLaxAJY1tRHy8IL2.jpg?size=75x75&quality=96&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 2000,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/4CmbHUt578AueyzAB6eklGiCRzK5t-3TxtsXioPqy18BqJsq-uH1NxWUqykdtH-EvRcf5AAT.jpg?size=2000x2000&quality=96&type=album',
#         'type': 'w',
#         'width': 2000},
#        {'height': 604,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/ghvxWVhwGAM9JKqxdKD1NiMDerXsY9sGFKAdZ8SSxkVROU0ih3aRc7yeF7_VrMOv7uF8pmb9.jpg?size=604x604&quality=96&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 807,
#         'url': 'https://sun9-38.userapi.com/s/v1/if1/vuVj99u6MjwcD_30_a8sZIAEsL5lMchmgjtyui7FLvgIkupTmWq6CDVCU5lc5QV03H3n6ng9.jpg?size=807x807&quality=96&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height':

#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '🇷🇺 Михаил Юрьевич говорит, что уже 3 года не надевал пиджак с медалями потому, что ему запрещали праздновать 9 мая. Но это не правда. Сохранилось видео, где мэр в прошлом году лично поздравляет ветерана при параде. \n\nПропаганда и общественное давление способны убедить человека (особенно беззащитного) в чём угодно. Не стоит ненавидеть тех, кого сломила пропаганда. Они не злодеи, а жертвы.\n\nА вот оно: https://t.me/voenacher/15807',
#    'attachments': [{'type': 'video',
#      'video': {'access_key': 'a29df5d12c9a7548b3',
#       'can_comment': 1,
#       'can_like': 1,
#       'can_repost': 1,
#       'can_subscribe': 1,
#       'can_add_to_faves': 1,
#       'can_add': 1,
#       'comments': 5,
#       'date': 1650750527,
#       'description': '',
#       'duration': 91,
#       'image': [{'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=4300c4c1e1d0ae94e56f9c4e35eb6a41&c_uniq_tag=6uv-uYR82tsVUI3jphqeqRY8LXAKerxTzQJYAT6KIXo&type=video_thumb',
#         'width': 130,
#         'height': 96,
#         'with_padding': 1},
#        {'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=160x120&quality=96&keep_aspect_ratio=1&background=000000&sign=59fb7e2b61014ce5c3ac0b9c5228c84b&c_uniq_tag=wlPXzxnaGApbUHR1_AYOV46F0P3oHghIDdnmfLLHhI0&type=video_thumb',
#         'width': 160,
#         'height': 120,
#         'with_padding': 1},
#        {'url': 'https://sun1-91.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=73935a735efe46078117ae0c51b85de3&c_uniq_tag=WxkmBc7zYQl59Mn16HrnjimEps2B9bS76785cwnUTbo&type=video_thumb',
#         'width': 320,
#         'height': 240,
#         'with_padding': 1},
#        {'url': 'https://sun1-91.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=29f8c274e2da95fd0a944d1b829733bc&c_uniq_tag=bcG6yRMrmKd3JMSW_jCWWPHlFUvixh1BvC4BR3Na_JY&type=video_thumb',
#         'width': 800,
#         'height': 450,
#         'with_padding': 1},
#        {'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=1280x720&quality=96&sign=ebfd023e67609745e29d499a9f98f6e5&c_uniq_tag=l1ljVokqLyvHzWmVhlEnJ0lh1sML5RUNJUZ3Je-Kk9A&type=video_thumb',
#         'width': 1280,
#         'height': 720},
#        {'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=320x180&quality=96&sign=bbb52df7392a49422c9dca73dd62d5ef&c_uniq_tag=05tKPh8JKw-lzJSaMxWGVzhb2VRSuDVWv4IimdkNVeg&type=video_thumb',
#         'width': 320,
#         'height': 180},
#        {'url': 'https://sun1-91.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=720x405&quality=96&sign=0fd1d25e15eaba41c053339dd814f0ef&c_uniq_tag=oucengHqG2zX9Wu2rzBeZ35Zcoaos7PkKHrL6ltIM1E&type=video_thumb',
#         'width': 720,
#         'height': 405},
#        {'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=1024x576&quality=96&sign=9aa3c658e527fde3125e152b980b64c2&c_uniq_tag=nFHPhOBB-tVaUeWOpnGyALmu-JVM7DCN0R4D0f1Q5GA&type=video_thumb',
#         'width': 1024,
#         'height': 576},
#        {'url': 'https://sun9-78.userapi.com/impf/UMKuN9ivEhfwz9Dxqj5Po-q4FT1NGw4x-RGM9g/1_IlPqMXEkw.jpg?size=0x0&quality=90&proxy=1&sign=03f1d8b496e42747c8235a46ce95011f&c_uniq_tag=XuDfVAn1j2R-zq0BUnRr-Up8y9H1RHAKDu7CwARXUbs&type=video_thumb',
#         'width': 4096,
#         'height': 2304}],
#       'first_frame': [{'url': 'https://i.mycdn.me/getVideoPreview?id=2371198323323&idx=0&type=39&tkn=WmOann2dOpfXXCI1Jw0beeqaGSA&fn=vid_f',
#         'width': 720,
#         'height': 405},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2371198323323&idx=0&type=39&tkn=WmOann2dOpfXXCI1Jw0beeqaGSA&fn=vid_md',
#         'width': 480,
#         'height': 270},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2371198323323&idx=0&type=39&tkn=WmOann2dOpfXXCI1Jw0beeqaGS
quality=95&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun9-5.userapi.com/s/v1/if2/bLyoO055-dqncNWjAKGxMQg70GOQ7Towllkk-cqzKFDBLxQCzSYunKVxOc2tiLkJc2UnZ9yMoc0PLkwqffL7SLpu.jpg?size=510x340&quality=95&crop=1,0,727,485&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 24, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 45, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 31, 'user_reposted': 0},
#    'views': {'count': 1982},
#    'copyright': {'link': 'https://t.me/west_info',
#     'type': 'external_link',
#     'name': 't.me'},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'edited': 1650829807,
#    'hash': 'eYG41T0DwNS2vFh8IZCID_OG3v2e'},
#   {'id': 317794,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1650811500,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '👨\u200d⚖️ На суде Джонни Деппа изучают аудио с признанием Эмбер Хёрд в избиении мужа\n\nНа записи Хёрд объясняет, что она мужа стукнула, но не била. Женщина напоминает, что Депп участвовал в драках — и должен знать разницу. Изначально в рамках бракоразводного процесса Эмбер Хёрд обвиняла мужа в домашнем насилии, но её доказательства оказались говном.\n\nБыть мужчиной значит платить и каяться. Шаг вправо — домашнее насилие. Шаг влево — ты чё, не мужик?\n\n#Fucking_Liberals@west_info',
#    'attachments': [{'type': 'video',
#      'video': {'access_key': '3bcd097c347d341b0c',
#       'can_comment': 1,
#       'can_like': 1,
#       'can_repost': 1,
#       'can_subscribe': 1,
#       'can_add_to_faves': 1,
#       'can_add': 1,
#       'comments': 15,
#       'date': 1650636803,
#       'description': '',
#       'duration': 76,
#       'image': [{'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=2dc4fa0522ef74b68d699897b1d7e9d5&c_uniq_tag=sFfMutw4Bke0UxCuhlqSDK0w5LMk5-tJe31dheOiXFk&type=video_thumb',
#         'width': 130,
#         'height': 96,
#         'with_padding': 1},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=160x120&quality=96&keep_aspect_ratio=1&background=000000&sign=a895306d552c1b49a4606b2a725da3ad&c_uniq_tag=xr-qwUd3yCovkiE8wbxlCr3e-ItlV1sPRV_W-jLXn2o&type=video_thumb',
#         'width': 160,
#         'height': 120,
#         'with_padding': 1},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=ade2769f3b66ad7211edcd49d587a418&c_uniq_tag=ImoMHAbIkNJ8eZ5AMntbRTT_Q8rVlVZ62eP9ZhrMDzs&type=video_thumb',
#         'width': 320,
#         'height': 240,
#         'with_padding': 1},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=f610875074e89f4a038dbcb64164092e&c_uniq_tag=mmXPFd3vNeoU-SgiPnq_mXHC9z_xzhy2JNJo8c-qYyc&type=video_thumb',
#         'width': 800,
#         'height': 450,
#         'with_padding': 1},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=1280x700&quality=96&sign=38e23502e393dab5f70b2218280de207&c_uniq_tag=GehYRlnF8EF9AH6DsOwd0Wrrf6HTqzEjljPTz3VVp20&type=video_thumb',
#         'width': 1280,
#         'height': 700},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=320x175&quality=96&sign=b87197b90e1b6f10dd84aae67dcdf699&c_uniq_tag=Li6nfJ2CeRbUVEQcUGcYEYrf7cV_4fr0d-_uVWAVfBI&type=video_thumb',
#         'width': 320,
#         'height': 175},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=720x394&quality=96&sign=8e37990eccbcb79b011b31e261a648e2&c_uniq_tag=2g7Tt6u-xOKmao3f54B-nXV0qVSwpSln14zq8ukYWk8&type=video_thumb',
#         'width': 720,
#         'height': 394},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=1024x560&quality=96&sign=22d05284f45ad20836f304e5f85179f8&c_uniq_tag=C2gsXR-90mlRPjRK4My2NRR2Hy685NnqirF38UEW5hQ&type=video_thumb',
#         'width': 1024,
#         'height': 560},
#        {'url': 'https://sun9-46.userapi.com/impf/cfNaJaxCZ4niAuCPaRZUgu7ercaaBm044-QXXQ/FZ0iS_XWrVM.jpg?size=0x0&quality=90&proxy=1&sign=8b9d6e6d1a324cf0fccee8038fd4ffac&c_uniq_tag=HCiqQVxcdC-dJvrt4KcF14fxFj77QTUny6vENTBLBQY&type=video_thumb',
#         'width': 4096,
#         'height': 2241}],
#       'first_frame': [{'url': 'https://i.mycdn.me/getVideoPreview?id=2428422589066&idx=0&type=39&tkn=qxXF7sli4gc6z2jYVOkpZ_vB6KQ&fn=vid_f',
#         'width': 720,
#         'height': 394},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2428422589066&idx=0&type=39&tkn=qxXF7sli4gc6z2jYVOkpZ_vB6KQ&fn=vid_md',
#         'width': 480,
#         'height': 263},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2428422589066&idx=0&type=39&tkn=qxXF7sli4gc6z2jYVOkpZ_vB6KQ&fn=vid_d',
#         'width': 240,
#         'height': 131},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2428422589066&idx=0&type=39&tkn=qxXF7sli4gc6z2jYVOkpZ_vB6KQ&fn=vid_sm',
#         'width': 128,
#         'height': 70},
#        {'url': 'https://i.mycdn.me/getVideoPreview?id=2428422589066&idx=0&type=39&tkn=qxXF7sli4gc6z2jYVOkpZ_vB6KQ',
#         'width': 1280,
#         'height': 700}],
#       'width': 852,
#       'height': 466,
#       'id': 456240884,
#       'owner_id': -42744677,
#       'title': 'Видео от Westerly',
#       'is_favorite': False,
#       'track_code': 'video_6dbaabf6up784PPML4eG4-XHueNxcti42Mi3NiTXePu50JJ0bCaMuefj9qQogofj66yN1kdA7Ijg8IMyU7YUlw',
#       'type': 'video',
#       'views': 3870}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 15, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 117, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 31, 'user_reposted': 0},
#    'views': {'count': 3066},
#    'copyright': {'link': 'https://t.me/west_info',
#     'type': 'external_link',
#     'name': 't.me'},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': 'SClvjAEZ0xZXu4CNzpjEk9UVQusU'},
#   {'id': 317785,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1650807900,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 19887,
#      'owner_id': -182525523,
#      'from_id': -182525523,
#      'date': 1650802097,
#      'post_type': 'post',
#      'text': 'Так вышло, что вместо того, чтобы найти в себе мужество и признать ошибки, pycичи старательно выискивают причины собственных личных просчётов где-то на стороне. И тогда перед нами открывается бесконечный список соломенных чучел из числа "врагов русского мира": начиная от жидo-рeптилoидов с фaшиcтaми и заканчивая, собственно, армянами. Не подскажете, а это исторически так сложилось или какая-то уникальная гeнeтическая особенность?..',
#      'attachments': [{'type': 'photo',
#        'photo': {'album_id': -7,
#         'date': 1650802092,
#         'id': 457263957,
#         'owner_id': -182525523,
#         'access_key': '5fdd13720e501d9dd2',
#         'post_id': 19887,
#         'sizes': [{'height': 56,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/ofQ87xQRQJKZqdyVWFJXXog4iYB4QULFcz4ca14Oj7NXeNyTk7USstfnqBaME8DM6pzFw9LWSIQvFA4881lC4W2r.jpg?size=75x56&quality=95&type=album',
#           'type': 's',
#           'width': 75},
#          {'height': 97,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/UtKd1OMwIb4KIe2qN6LMAkI6_pOIK5RDlaIWl_yqa7kxUxD6h4SfdBgjY8QPNHEwORwDTSz49zOlv3g49aMRoQ2Q.jpg?size=130x97&quality=95&type=album',
#           'type': 'm',
#           'width': 130},
#          {'height': 453,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/zprMS3TUDtxQEbBRaYcQJTTWYHZ8lpP9A3gTv-3OrAId3IPT5a6HqldUE616_2hAQy8swDClux5hWFhjw6zOOOMU.jpg?size=604x453&quality=95&type=album',
#           'type': 'x',
#           'width': 604},
#          {'height': 605,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/AvI-lFMZUr93n5vCks2mhYdBi_4oj1LASW04mjn84ChgPmVppu_1WY9-1hYTvqEVyygffxOgCct8wRVSIqQjZOvu.jpg?size=807x605&quality=95&type=album',
#           'type': 'y',
#           'width': 807},
#          {'height': 960,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/ARyz_pcCPVF9Kudnh-Es-WFmky0wxNsX_VrbhveVowYeSLuILLq-8XhaKQVEOj5478a9-BaSkkj63Dg0a_u15zwI.jpg?size=1280x960&quality=95&type=album',
#           'type': 'z',
#           'width': 1280},
#          {'height': 1920,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/FSe_-pzwG7wKV4eSkiFpnOFaDOXa41lU7hCeduGpBm0W8h-CRb8aZZAsxeMVLRTlix0EPt2Stm8kepyA75Wn2jO4.jpg?size=2560x1920&quality=95&type=album',
#           'type': 'w',
#           'width': 2560},
#          {'height': 97,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/UtKd1OMwIb4KIe2qN6LMAkI6_pOIK5RDlaIWl_yqa7kxUxD6h4SfdBgjY8QPNHEwORwDTSz49zOlv3g49aMRoQ2Q.jpg?size=130x97&quality=95&type=album',
#           'type': 'o',
#           'width': 130},
#          {'height': 150,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/Hzm5gOcBlPjiFgcUD-Tce4AzA2i_5AcS5R6yx_FN0Ka8OgZT9AMTiOqgKrAg6GrY2SOk5THkIXRsazeA6ziU5KR9.jpg?size=200x150&quality=95&type=album',
#           'type': 'p',
#           'width': 200},
#          {'height': 240,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/Xn1fRr7WguWMlYevL6wrc-_8p4utflZKz0MnnHT6l-CL4midSIjd5WxLAV-AdAu5WpylhD6sHdjZdIfmCvJch01C.jpg?size=320x240&quality=95&type=album',
#           'type': 'q',
#           'width': 320},
#          {'height': 382,
#           'url': 'https://sun9-6.userapi.com/s/v1/ig2/CozfAmNcBVFR36TpRpO3oQm6B9LmrSau4djPL5JILxnFIr5CJX-dtfmwFptBnH9Co4OfaDNP1-A2So0RW4Ougqf5.jpg?size=510x382&quality=95&type=album',
#           'type': 'r',
#           'width': 510}],
#         'text': '',
#         'user_id': 100,
#         'has_tags': False}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 9, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 35, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'views': {'count': 1511},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': 'Gn0Kh3exR7SNsNv53wccePJgiPXk'},
#   {'id': 317745,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1650790500,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '🇫🇷 Я не за Ле Пен, но ситуация с феминистками против женщин политиков смешная. \n\nСегодня, кстати, второй тур президентских выборов во Франции. Ле Пен vs Макрон. Легко включить эскобара и сказать, что оба кандидата говно. Но хотим мы или нет, победит один из них. И я болею за Макрона. \n\nОбъясняю почему. Я много раз писал про причины не любить Макрона. Но давайте посмотрим на ситуацию с другой стороны. Французы сами вывели в топ двоих мерзких кандидатов. Это их выбор. Мы с вами тут никаким французам не объясним ничего. И в сравнении с Ле Пен, Макрон не такой явный враг Европы  \n
],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 10, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'views': {'count': 2589},
#    'copyright': {'link': 'https://t.me/MainMedicChannel',
#     'type': 'external_link',
#     'name': 't.me'},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': 'n2XzKLPGnXQ5wG6G09Y_b0Br0Rtz'},
#   {'id': 314098,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1648975682,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': '🇫🇷 Четверо грабителей ворвались в дом, где был отец с трёхлетним ребёнком. Мужчина застрелил одного из грабителей и был обвинен в убийстве. \n\nУ Макрона спросили, что он об этом думает — Президент ответил, что самооборона — это беспредел.\n\n«Я возражаю против легитимной самообороны. Это очевидно и бесспорно, потому что если ее поддерживать, мы скатимся в Дикий Запад. И я не хочу страну, в которой распространено оружие и граждане сами себя защищают. \n\nhttps://www.europe1.fr/politique/je-suis-oppose-a-la-legitime-defense-la-reaction-de-macron-au-meurtre-dun-cambrioleur-4103037',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': 199077547,
#       'date': 1596362868,
#       'id': 457294661,
#       'owner_id': 109145547,
#       'access_key': '1eff4a3d7e78215a36',
#       'sizes': [{'height': 130,
#         'url': 'https://sun1-14.userapi.com/s/v1/if2/FKZaTmpTJ4tK6Xu-Y3X1YvxD5g04yxszJcJl_MMPoIe-E6JZKx5VUMZmcBeZ1sKJThWHB__AnsDcFzFFVnEudpDo.jpg?size=130x130&quality=96&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 130,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/FKZaTmpTJ4tK6Xu-Y3X1YvxD5g04yxszJcJl_MMPoIe-E6JZKx5VUMZmcBeZ1sKJThWHB__AnsDcFzFFVnEudpDo.jpg?size=130x130&quality=96&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 200,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/3vv02jne11MuQrK1KKTxDy2KO4J15Nl4XJHDEnCab6QSP5je7oJGlx9BJIrTnROiUhjpoMcphlblSMEj14e9a33j.jpg?size=200x200&quality=96&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 320,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/WeEwfC1aHC5UmmDtu3zgwF5tywIvi89-4JaOVLSGDAd8qb3gZ6vwfmE2F11ycSf8Tpc0w5BDFig6Owz3Nz3KWtTR.jpg?size=320x320&quality=96&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 510,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/GG524K1waLhuAbxRaq3ofyFKlfW5tchwz89Rhg0_RN6RdoM9LE5pXmKsXiDxZz-GluAwNdMoUdmpsJnHe29PHT_6.jpg?size=510x510&quality=96&type=album',
#         'type': 'r',
#         'width': 510},
#        {'height': 75,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/t4OnCszjNvTRwjn4ta_OOv7WkCQg5cWKR8hoaJZYddGpRiJqVHiNupdPFufTwwOCLrW7Gtu__Qn_2YLYHbAlsHFi.jpg?size=75x75&quality=96&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 600,
#         'url': 'https://sun9-14.userapi.com/s/v1/if2/0tJWeI0-ck6dqizkDQ1S-36l93PB_pABORVFdUXrcYCoKeNRVNerW1JKP1ALLJkVylVHaWr5hi66A0X3Hv6DLOVf.jpg?size=600x600&quality=96&type=album',
#         'type': 'x',
#         'width': 600}],
#       'text': '',
#       'has_tags': False}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 59, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 252, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 151, 'user_reposted': 0},
#    'views': {'count': 8754},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': '2tdWghD1xJ6JEwHos85phJiPeeJd'},
#   {'id': 314048,
#    'from_id': -42744677,
#    'owner_id': -42744677,
#    'date': 1648931521,
#    'marked_as_ads': 0,
#    'is_favorite': False,
#    'post_type': 'post',
#    'text': 'Подписывайся на tg канал Westerly! \n\nЭто не тупое копирование постов из группы. Это на 90% уникальный контент, которого там больше, чем в VK. Так что не выключай уведомления и следи за новостями. Ссылка в источнике👇🏻',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1648931521,
#       'id': 457270146,
#       'owner_id': -42744677,
#       'access_key': 'f4aee55dfcd75aa6e1',
#       'post_id': 314048,
#       'sizes': [{'height': 75,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/q0OvxkhMsImeL6OXxPrXh6AqzR3c04V3hKP5HGU9il2cZrjfPoCtoojt0HqB69qHpqL-DNq8VIrk7JQ7vHpbm3xO.jpg?size=75x75&quality=95&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 130,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/j_QvQroLSQDSqma9maE12szsfU9xxctTveaaR14hVVuadhPfsX_4f8hWRhhqRLC-lDqg-SpBTJhJrCgUF26V2kFN.jpg?size=130x130&quality=95&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 604,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/65F1SHkvj1cvtXIpfUzKes7T-BsrmSpdUZPWgbjDc842yxx-H8CSJkqckl50rZhg7g0VRoxj5FfN2tX7E0b3uDRQ.jpg?size=604x604&quality=95&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 736,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/PQr_Ou_zl2NZG8FlJy1J60zqsNO192jJo5KMW9SqIfbLR91uquYra3tVK_VplI9Uzvve3-EEFHX_kPhL95cHOvtB.jpg?size=736x736&quality=95&type=album',
#         'type': 'y',
#         'width': 736},
#        {'height': 130,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/j_QvQroLSQDSqma9maE12szsfU9xxctTveaaR14hVVuadhPfsX_4f8hWRhhqRLC-lDqg-SpBTJhJrCgUF26V2kFN.jpg?size=130x130&quality=95&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 200,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/8r96knU6KM4Q2xE6tH1d0nOYt-B-2DgyJNBI6EAzl_iK98o97lqYdJEMKi1fTKLWIZ49xM1WJHGTqzNgxOq7E_jd.jpg?size=200x200&quality=95&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 320,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/J5paO6RF_kB8HrIKKwS0XqXE_lJkhVa9h9rjI-c3m4J3gvHA7rhLyHMf80aniBI0aQusPFhVK6dpVa9PLaZbXTHl.jpg?size=320x320&quality=95&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 510,
#         'url': 'https://sun9-54.userapi.com/s/v1/if2/LHg-6PKgnChHR-ojscqeF3Gov327dwJYt-kMVCydHS5YMhT0h8ILZ3pVwUYnkGaj6S_C8k6ONrccDAObiJTpR2vq.jpg?size=510x510&quality=95&type=album',
#         'type': 'r',
#         'width': 510}],
#       'text': '',
#       'user_id': 100,
#       'has_tags': False}}],
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'comments': {'can_post': 1, 'count': 3, 'groups_can_post': True},
#    'likes': {'can_like': 1, 'count': 13, 'user_likes': 0, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 3042},
#    'copyright': {'link': 'https://t.me/westerly_info',
#     'type': 'external_link',
#     'name': 't.me'},
#    'donut': {'is_donut': False},
#    'short_text_rate': 0.8,
#    'hash': 'g8289iqTXMUvPn9fO15Dj3Iu022r'}]}

# %% [markdown]
# Результат, сохраненный в `res`, очень похож на словарь. На самом деле, многие API возвращают результаты в формате JSON (JavaScript Object Notation), который тоже может быть представлен в виде набора пар ключ-значение.

# %%
res.keys()
# Out:
# dict_keys(['count', 'items'])

# %% [markdown]
# Ключами являются `count` и `items`. Нужные нам объекты (текст постов, id автора, дата и время публикации и проч.) находятся в `items`.

# %%
res['items'][0] # первый элемент items - первый пост со всей информацией о нем
# Out:
# {'id': 33850,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1622395168,
#  'marked_as_ads': 0,
#  'is_favorite': False,
#  'post_type': 'post',
#  'text': 'УВАЖАЕМЫЕ УЧАСТНИКИ ГРУППЫ! В ТЕЧЕНИЕ ОЧЕНЬ МНОГИХ ЛЕТ Я ВЫПОЛНЯЛА ФУНКЦИИ АДМИНИСТРАТОРА ГРУППЫ, КОТОРЫЕ ПОЛУЧИЛА ПО НАСЛЕДСТВУ ОТ ОСНОВАТЕЛЕЙ ПАБЛИКА - ВЫПУСКНИКОВ ПИТЕРСКОЙ ВЫШКИ. В НАСТОЯЩЕЕ ВРЕМЯ Я УЖЕ НЕ ЯВЛЯЮСЬ СОТРУДНИКОМ НИУ ВШЭ И НЕ ВЛАДЕЮ АКТУАЛЬНОЙ ДЛЯ ВАС ИНФОРМАЦИЕЙ. Я ПРОЩАЮСЬ, БЛАГОДАРНА КОЛЛЕГАМ, СТУДЕНТАМ И ВЫПУСКНИКАМ ЗА ВНИМАНИЕ К ГРУППЕ И АКТИВНОЕ УЧАСТИЕ. \nС уважением,\nИ.Лесовская',
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 10, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 609, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 87, 'user_reposted': 0},
#  'views': {'count': 73846},
#  'hash': 'IUHhT7sG2ip-2cbnz-32iNz2cH2x'}

# %% [markdown]
# Помимо текста поста можно найти много всего интересного. Например, тип поста (`post_type`), дата (`date`), id поста (`id`), лайки (`likes`, которые включают информацию о том, могут ли пользователи лайкать пост и публиковать его, а также собственно число лайков), репосты (`reposts`, которые включают число репостов), число просмотров (`views`), комментарии (`comments`, которые включают информацию о том, могут ли пользователи комментировать пост, и число комментариев), и так далее.

# %% [markdown]
# Давайте остановимся на тексте поста, id автора, id поста, дате публикации, числе лайков и репостов. Чтобы извлечь соответствующую информацию, сохраним `items` и извлечем из них нужные поля:

# %%
items = res['items']

# %%
full_list = []

for item in items:
    L = [item['from_id'], item['id'], item['text'], item['date'],
        item['likes']['count'], item['reposts']['count']]  # нужные поля
    full_list.append(L)  # добавляем в список списков full_list

# %%
# несколько элементов списка
full_list[0:3]
# Out:
# [[-132,
#   33850,
#   'УВАЖАЕМЫЕ УЧАСТНИКИ ГРУППЫ! В ТЕЧЕНИЕ ОЧЕНЬ МНОГИХ ЛЕТ Я ВЫПОЛНЯЛА ФУНКЦИИ АДМИНИСТРАТОРА ГРУППЫ, КОТОРЫЕ ПОЛУЧИЛА ПО НАСЛЕДСТВУ ОТ ОСНОВАТЕЛЕЙ ПАБЛИКА - ВЫПУСКНИКОВ ПИТЕРСКОЙ ВЫШКИ. В НАСТОЯЩЕЕ ВРЕМЯ Я УЖЕ НЕ ЯВЛЯЮСЬ СОТРУДНИКОМ НИУ ВШЭ И НЕ ВЛАДЕЮ АКТУАЛЬНОЙ ДЛЯ ВАС ИНФОРМАЦИЕЙ. Я ПРОЩАЮСЬ, БЛАГОДАРНА КОЛЛЕГАМ, СТУДЕНТАМ И ВЫПУСКНИКАМ ЗА ВНИМАНИЕ К ГРУППЕ И АКТИВНОЕ УЧАСТИЕ. \nС уважением,\nИ.Лесовская',
#   1622395168,
#   609,
#   87],
#  [-132,
#   33848,
#   'Добрый день! У Russian Hackers новый крутой Data Science хакатон. На этот раз от известного ретейлера “Ленты” при поддержке менторов из Microsoft. \n \nХакатон Hack.Promo от «Ленты» при поддержке менторов Microsoft! \n \nПриглашаем решить задачу повышения эффективности промоакций в Big Media на основе чековых данных случайных посетителей «Ленты», а именно: \n– Построить предсказательную Uplift модель для промоакций \n– Предложить оптимальный промо-календарь (набор промоакций с указанием их типа, периода проведения, наполнения по SKU) \n \nУчастников и победителей ждут: \n🔹 Помощь экспертов из «Ленты» \n🔹 Технологическая поддержка от Microsoft \n🔹 Упрощённое трудоустройство в «Ленту» \n🔹 Главный приз: 222 000 ₽ \n🔹 Возможность поработать с уникальным датасетом, различные активности и отличная компания \n \nhttp://rhck.me/hackpromovk',
#   1622114845,
#   17,
#   30],
#  [-132, 33846, '', 1621322422, 9, 12]]

# %% [markdown]
# Видно, что в некоторых постах текста не обнаружено.

# %% [markdown]
# Из этого списка списков можно легко сделать датафрейм `pandas`. Но прежде посмотрим, как сгрузить следующие 100 (и не только 100) постов со стены. Обычно при работе с API нужно принимать во внимание две вещи: 1) какое ограничение стоит на число запросов за один раз (число постов в нашем случае); 2) какое ограничение стоит на число запросов в минуту. Чтобы действовать в соответствии с этими ограничениями, поступим так: будем грузить каждые следующие 100 постов, добавлять их к нашему списку, потом немного ждать, и грузить еще 100 постов, и так до тех пор, пока не сгрузим желаемое количество.
#
# Давайте для начала выберем это желаемое число постов. Пусть будет 400.

# %%
nposts = 400

# %% [markdown]
# Теперь вопрос: по каким значениям нужно «пробегаться» в цикле, чтобы сгрузить посты с 100 по 400 (первые 100 уже сохранены в `res`)? По целым значениям от 2 до 4 включительно, умножая эти значения на 100. В `vk.get` есть опция `offset`. Она позволяет сдвинуть начало отсчета постов на некоторое число. Так, если мы напишем `api.wall.get(domain = group, count = 100, offset = 100, v = 5.73)`,  мы получим посты с 100 по 200, так как начало отсчета сдвинулось на 100.

# %% [markdown]
# Реализуем описанное выше. Для цикла нам понадобится `range()`, а для задержки после выгрузки каждой сотни постов нам пригодится функция `sleep`:

# %%
from time import sleep

# %%
for i in range(1, 3):
    res2 = api.wall.get(domain = group, count = 100, offset = 100 * i, v = 5.131)
    items2 = res2['items']
    items.extend(items2) # добавляем к первой сотне постов в items
    sleep(0.5)

# %%
# опять выберем только нужные поля
full_list = []
for item in items:
    L = [item['from_id'], item['id'], item['text'], item['date'],
        item['likes']['count'], item['reposts']['count']]
    full_list.append(L)

# %% [markdown]
# Оставлось превратить обновленный список `items` (список списков) в датафрейм. Импортируем `pandas`.

# %%
import pandas as pd

# %% [markdown]
# Создадим датафрейм:

# %%
df = pd.DataFrame(full_list)

# %%
df.head(10)
# Out:
#      0      1                                                  2           3  \
# 0 -132  33850  УВАЖАЕМЫЕ УЧАСТНИКИ ГРУППЫ! В ТЕЧЕНИЕ ОЧЕНЬ МН...  1622395168
# 1 -132  33848  Добрый день! У Russian Hackers новый крутой Da...  1622114845
# 2 -132  33846                                                     1621322422
# 3 -132  33844  Приглашает студентов "Сириус" в летнюю школу п...  1621322182
# 4 -132  33837  Студенты Вышки без жилья не останутся https://...  1620224327
# 5 -132  33836  Прошла традиционная Апрельская конференция. Ит...  1620224186
# 6 -132  33834                                                     1619763780
# 7 -132  33833  Новая ступень для роста в профессии. \n \nМаги...  1619763619
# 8 -132  33830  Вакансия для программистов С++:\nhttps://felen...  1619382651
# 9 -132  33829  Вакансия для факультета права:\nФедеральное го...  1619382567
#
#      4   5
# 0  609  87
# 1   17  30
# 2    9  12
# 3   10  12
# 4   40  84
# 5    4   5
# 6   11  13
# 7    9   6
# 8    5   7
# 9    4  12

# %% [markdown]
# Ура! Осталось только дать внятные названия столбцам и разобраться, почему дата представлена в таком виде. что делать со столбцами, мы уже знаем.

# %%
df.columns = ['from_id', 'id', 'text', 'date', 'likes', 'reposts']
df.head(10)
# Out:
#    from_id     id                                               text  \
# 0     -132  33850  УВАЖАЕМЫЕ УЧАСТНИКИ ГРУППЫ! В ТЕЧЕНИЕ ОЧЕНЬ МН...
# 1     -132  33848  Добрый день! У Russian Hackers новый крутой Da...
# 2     -132  33846
# 3     -132  33844  Приглашает студентов "Сириус" в летнюю школу п...
# 4     -132  33837  Студенты Вышки без жилья не останутся https://...
# 5     -132  33836  Прошла традиционная Апрельская конференция. Ит...
# 6     -132  33834
# 7     -132  33833  Новая ступень для роста в профессии. \n \nМаги...
# 8     -132  33830  Вакансия для программистов С++:\nhttps://felen...
# 9     -132  33829  Вакансия для факультета права:\nФедеральное го...
#
#          date  likes  reposts
# 0  1622395168    609       87
# 1  1622114845     17       30
# 2  1621322422      9       12
# 3  1621322182     10       12
# 4  1620224327     40       84
# 5  1620224186      4        5
# 6  1619763780     11       13
# 7  1619763619      9        6
# 8  1619382651      5        7
# 9  1619382567      4       12

# %% [markdown]
# С датой все интереснее. То, что указано в столбце `date`, это дата в виде UNIX-времени (POSIX-времени). Это число секунд, прошедших с 1 января 1970 года. Несмотря на то, что такой формат даты-времени кажется необычным, он довольно широко распространен в разных системах и приложениях (см. подробнее [здесь](https://ru.wikipedia.org/wiki/Unix-%D0%B2%D1%80%D0%B5%D0%BC%D1%8F)). Этот факт, конечно, радует, но хочется получить дату в более человеческом формате. Давайте напишем функцию для перевода UNIX-времени в формат *год-месяц-день-часы-минуты-секунды*. Для этого нам понадобится модуль *datetime*.

# %%
from datetime import datetime

# %%
def date_norm(date):
    d = datetime.fromtimestamp(date) # timestamp - UNIX-время в виде строки
    str_d = d.strftime("%Y-%m-%d %H:%M:%S") # %Y-%m-%d %H:%M:%S - год-месяц-день, часы:мин:сек
    return str_d

# %% [markdown]
# Применим нашу функцию к элементам столбца *date* и создадим новый – *date_norm*.

# %%
df['date_norm'] = df.date.apply(date_norm)

# %%
df.head()
# Out:
#    from_id     id                                               text  \
# 0     -132  33850  УВАЖАЕМЫЕ УЧАСТНИКИ ГРУППЫ! В ТЕЧЕНИЕ ОЧЕНЬ МН...
# 1     -132  33848  Добрый день! У Russian Hackers новый крутой Da...
# 2     -132  33846
# 3     -132  33844  Приглашает студентов "Сириус" в летнюю школу п...
# 4     -132  33837  Студенты Вышки без жилья не останутся https://...
#
#          date  likes  reposts            date_norm
# 0  1622395168    609       87  2021-05-30 20:19:28
# 1  1622114845     17       30  2021-05-27 14:27:25
# 2  1621322422      9       12  2021-05-18 10:20:22
# 3  1621322182     10       12  2021-05-18 10:16:22
# 4  1620224327     40       84  2021-05-05 17:18:47

# %% [markdown]
# Можно разбить на части дату и время, а не сохранять одной строкой. Для этого нужно применить метод `.split()` для строк и «раздвинуть» столбцы – после разбиения получить не один столбец, а сразу несколько.

# %%
df['date_norm'].str.split() # результат разбиения – набор списков
# Out:
# 0      [2021-05-30, 20:19:28]
# 1      [2021-05-27, 14:27:25]
# 2      [2021-05-18, 10:20:22]
# 3      [2021-05-18, 10:16:22]
# 4      [2021-05-05, 17:18:47]
#                 ...
# 295    [2018-07-20, 21:27:23]
# 296    [2018-07-19, 12:12:51]
# 297    [2018-07-16, 20:06:27]
# 298    [2018-07-16, 18:47:02]
# 299    [2018-07-13, 19:11:20]
# Name: date_norm, Length: 300, dtype: object

# %%
df['date_norm'].str.split(expand = True) # теперь расширили – 2 столбца
# Out:
#               0         1
# 0    2019-12-10  12:57:29
# 1    2019-12-10  12:54:25
# 2    2019-12-10  12:53:45
# 3    2019-12-10  12:53:06
# 4    2019-12-10  12:50:33
# ..          ...       ...
# 295  2018-01-23  14:43:19
# 296  2018-01-17  08:50:56
# 297  2018-01-10  11:32:29
# 298  2018-01-10  11:24:29
# 299  2018-01-05  15:13:01
#
# [300 rows x 2 columns]

# %%
new_dat = df['date_norm'].str.split(expand = True) # сохраняем
df['Date'] = new_dat[0] # первый столбец – в Date
df['Time'] = new_dat[1]  # второй столбец – в Time

# %%
df.head()
# Out:
#    from_id     id                                               text  \
# 0     -132  33029                                  Что меня огорчает
# 1     -132  33028
# 2     -132  33027
# 3     -132  33026
# 4     -132  33025  Вышка в прошлом году запустила новый проект, о...
#
#          date  likes  reposts            date_norm        Date      Time
# 0  1575971849      8        0  2019-12-10 12:57:29  2019-12-10  12:57:29
# 1  1575971665     13        2  2019-12-10 12:54:25  2019-12-10  12:54:25
# 2  1575971625      4        0  2019-12-10 12:53:45  2019-12-10  12:53:45
# 3  1575971586      8        1  2019-12-10 12:53:06  2019-12-10  12:53:06
# 4  1575971433      8        0  2019-12-10 12:50:33  2019-12-10  12:50:33

# %% [markdown]
# Всё! Материалы о разных методах и функциях для `vk.api` можно найти в [официальной документации](https://vk.com/dev/manuals).
